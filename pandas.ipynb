# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
import matplotlib 
df=pd.read_csv("Bengaluru_House_Data.csv")

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.groupby("area_type")["area_type"].agg("count")
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
df1=df.drop(['area_type','society','balcony','availability'],axis='columns')
df1.shape
# Out:
# (13320, 5)

# %%
df1.tail()
# Out:
#                     location       size total_sqft  bath  price
# 13315             Whitefield  5 Bedroom       3453   4.0  231.0
# 13316          Richards Town      4 BHK       3600   5.0  400.0
# 13317  Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.0
# 13318        Padmanabhanagar      4 BHK       4689   4.0  488.0
# 13319           Doddathoguru      1 BHK        550   1.0   17.0

# %%
df1.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df2=df1.dropna()
df2.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13246 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13246 non-null  object
#  1   size        13246 non-null  object
#  2   total_sqft  13246 non-null  object
#  3   bath        13246 non-null  float64
#  4   price       13246 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 620.9+ KB

# %%
df2['bhk']=df2['size'].apply(lambda x: int(x.split(' ')[0]))
# Out:
# <ipython-input-31-d97910c39351>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['bhk']=df2['size'].apply(lambda x: int(x.split(' ')[0]))

# %%
df2[df2.bhk>20]
# Out:
#                        location        size total_sqft  bath  price  bhk
# 1718  2Electronic City Phase II      27 BHK       8000  27.0  230.0   27
# 4684                Munnekollal  43 Bedroom       2400  40.0  660.0   43

# %%
data = {
...     'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
...     'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai',
...              'Manchester', 'Cairo', 'Osaka'],
...     'age': [41, 28, 33, 34, 38, 31, 37],
...     'py-score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]
... }

>>> row_labels = [101, 102, 103, 104, 105, 106, 107]

# %%
df=pd.DataFrame(data=data,index=row_labels)

# %%
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
df.city
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# Name: city, dtype: object

# %%
df.loc[104]
# Out:
# name              Yi
# city        Shanghai
# age               34
# py-score        80.0
# Name: 104, dtype: object

# %%
d={"x":[1,2,3],"y":np.array([2,4,8]),"z":100}
pd.DataFrame(d)
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
l = [{'x': 1, 'y': 2, 'z': 100},
         {'x': 2, 'y': 4, 'z': 100},  
     {'x': 3, 'y': 8, 'z': 100}]
pd.DataFrame(l)
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
df1.shape
# Out:
# (13320, 5)

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=13320, step=1)

# %%
df1.columns
# Out:
# Index(['location', 'size', 'total_sqft', 'bath', 'price'], dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13319 non-null  object
#  1   size        13304 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13247 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
df1.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df1.memory_usage()
# Out:
# Index            128
# location      106560
# size          106560
# total_sqft    106560
# bath          106560
# price         106560
# dtype: int64

# %%
df1.iloc[1:10,[0,1,4]]
# Out:
#              location       size   price
# 1    Chikka Tirupathi  4 Bedroom  120.00
# 2         Uttarahalli      3 BHK   62.00
# 3  Lingadheeranahalli      3 BHK   95.00
# 4            Kothanur      2 BHK   51.00
# 5          Whitefield      2 BHK   38.00
# 6    Old Airport Road      4 BHK  204.00
# 7        Rajaji Nagar      4 BHK  600.00
# 8        Marathahalli      3 BHK   63.25
# 9        Gandhi Bazar  6 Bedroom  370.00

# %%
df1.loc[1:100,["location","price"]]
# Out:
#                       location   price
# 1             Chikka Tirupathi  120.00
# 2                  Uttarahalli   62.00
# 3           Lingadheeranahalli   95.00
# 4                     Kothanur   51.00
# 5                   Whitefield   38.00
# 6             Old Airport Road  204.00
# 7                 Rajaji Nagar  600.00
# 8                 Marathahalli   63.25
# 9                 Gandhi Bazar  370.00
# 10                  Whitefield   70.00
# 11                  Whitefield  295.00
# 12          7th Phase JP Nagar   38.00
# 13                   Gottigere   40.00
# 14                    Sarjapur  148.00
# 15                 Mysore Road   73.50
# 16               Bisuvanahalli   48.00
# 17       Raja Rajeshwari Nagar   60.00
# 18       Ramakrishnappa Layout  290.00
# 19          Manayata Tech Park   48.00
# 20                     Kengeri   15.00
# 21                  Binny Pete  122.00
# 22                 Thanisandra  380.00
# 23                   Bellandur  103.00
# ...

# %%
df1.iloc[1:6:2, 0]
# Out:
# 1      Chikka Tirupathi
# 3    Lingadheeranahalli
# 5            Whitefield
# Name: location, dtype: object

# %%
abdellah=pd.Series(data=["Abdella","Casablanca",22,100],index=df.columns,name=17)

# %%
df=df.append(abdellah)

# %%
df
# Out:
#         name         city  age  py-score
# 101   Xavier  Mexico City   41      88.0
# 102      Ann      Toronto   28      79.0
# 103     Jana       Prague   33      81.0
# 104       Yi     Shanghai   34      80.0
# 105    Robin   Manchester   38      68.0
# 106     Amal        Cairo   31      61.0
# 107     Nori        Osaka   37      84.0
# 17   Abdella   Casablanca   22     100.0

# %%
df=df.drop(labels=[106])

# %%
df
# Out:
#         name         city  age  py-score
# 101   Xavier  Mexico City   41      88.0
# 102      Ann      Toronto   28      79.0
# 103     Jana       Prague   33      81.0
# 104       Yi     Shanghai   34      80.0
# 105    Robin   Manchester   38      68.0
# 107     Nori        Osaka   37      84.0
# 17   Abdella   Casablanca   22     100.0

# %%
df["equipe pref"]=np.array(["fc mexico","fc toronto","fc prague","fc china","MCU","fc osaka","wyada"])

# %%
df
# Out:
#         name         city  age  py-score equipe pref
# 101   Xavier  Mexico City   41      88.0   fc mexico
# 102      Ann      Toronto   28      79.0  fc toronto
# 103     Jana       Prague   33      81.0   fc prague
# 104       Yi     Shanghai   34      80.0    fc china
# 105    Robin   Manchester   38      68.0         MCU
# 107     Nori        Osaka   37      84.0    fc osaka
# 17   Abdella   Casablanca   22     100.0       wyada

# %%
df.insert(loc=4,column="continent",value=np.array(["amerique du sud","amerique du nord","europe","asie","europe","asie","afrique"])
    )
df
# Out:
#         name         city  age  py-score         continent equipe pref
# 101   Xavier  Mexico City   41      88.0   amerique du sud   fc mexico
# 102      Ann      Toronto   28      79.0  amerique du nord  fc toronto
# 103     Jana       Prague   33      81.0            europe   fc prague
# 104       Yi     Shanghai   34      80.0              asie    fc china
# 105    Robin   Manchester   38      68.0            europe         MCU
# 107     Nori        Osaka   37      84.0              asie    fc osaka
# 17   Abdella   Casablanca   22     100.0           afrique       wyada

# %%
#we use del to drop a column in dataframe del df["name_column"]
#df.drop(labels="name_column",axis="''")
# Out:
#         name         city  age  py-score
# 101   Xavier  Mexico City   41      88.0
# 102      Ann      Toronto   28      79.0
# 103     Jana       Prague   33      81.0
# 104       Yi     Shanghai   34      80.0
# 105    Robin   Manchester   38      68.0
# 107     Nori        Osaka   37      84.0
# 17   Abdella   Casablanca   22     100.0

# %%
df.sort_values(by="age",ascending=False)
# Out:
#         name         city  age  py-score         continent equipe pref
# 101   Xavier  Mexico City   41      88.0   amerique du sud   fc mexico
# 105    Robin   Manchester   38      68.0            europe         MCU
# 107     Nori        Osaka   37      84.0              asie    fc osaka
# 104       Yi     Shanghai   34      80.0              asie    fc china
# 103     Jana       Prague   33      81.0            europe   fc prague
# 102      Ann      Toronto   28      79.0  amerique du nord  fc toronto
# 17   Abdella   Casablanca   22     100.0           afrique       wyada

# %%
filter_=df["py-score"]>=85
filter_
# Out:
# 101     True
# 102    False
# 103    False
# 104    False
# 105    False
# 107    False
# 17      True
# Name: py-score, dtype: bool

# %%
df[filter_]
# Out:
#         name         city  age  py-score        continent equipe pref
# 101   Xavier  Mexico City   41      88.0  amerique du sud   fc mexico
# 17   Abdella   Casablanca   22     100.0          afrique       wyada

# %%
df.describe()
# Out:
#              age    py-score
# count   7.000000    7.000000
# mean   33.285714   82.857143
# std     6.473389    9.737018
# min    22.000000   68.000000
# 25%    30.500000   79.500000
# 50%    34.000000   81.000000
# 75%    37.500000   86.000000
# max    41.000000  100.000000

# %%
df.mean()
# Out:
# age         33.285714
# py-score    82.857143
# dtype: float64
